# %% [markdown]
# <a href="https://colab.research.google.com/github/starmaerker/Algorithmen-und-Datenstrukturen-in-Python/blob/master/Data_Exploration_Pandas_College_Major.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('salaries_by_college_major.csv')
df.head()
# Out:
#      Undergraduate Major  ...     Group
# 0             Accounting  ...  Business
# 1  Aerospace Engineering  ...      STEM
# 2            Agriculture  ...  Business
# 3           Anthropology  ...      HASS
# 4           Architecture  ...  Business
#
# [5 rows x 6 columns]

# %%
df["Starting Median Salary"].idxmax()
# Out:
# 43

# %%
df['Undergraduate Major'].loc[43]
# Out:
# 'Physician Assistant'

# %%
import pandas as pd
df = pd.read_csv("salaries_by_college_major.csv")
df.head()
# Out:
#      Undergraduate Major  ...     Group
# 0             Accounting  ...  Business
# 1  Aerospace Engineering  ...      STEM
# 2            Agriculture  ...  Business
# 3           Anthropology  ...      HASS
# 4           Architecture  ...  Business
#
# [5 rows x 6 columns]

# %%
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.isna()
# Out:
#     Undergraduate Major  ...  Group
# 0                 False  ...  False
# 1                 False  ...  False
# 2                 False  ...  False
# 3                 False  ...  False
# 4                 False  ...  False
# 5                 False  ...  False
# 6                 False  ...  False
# 7                 False  ...  False
# 8                 False  ...  False
# 9                 False  ...  False
# 10                False  ...  False
# 11                False  ...  False
# 12                False  ...  False
# 13                False  ...  False
# 14                False  ...  False
# 15                False  ...  False
# 16                False  ...  False
# 17                False  ...  False
# 18                False  ...  False
# 19                False  ...  False
# 20                False  ...  False
# 21                False  ...  False
# 22                False  ...  False
# 23                False  ...  False
# 24                False  ...  False
# ...

# %%
df.tail()
# Out:
#       Undergraduate Major  ...  Group
# 46             Psychology  ...   HASS
# 47               Religion  ...   HASS
# 48              Sociology  ...   HASS
# 49                Spanish  ...   HASS
# 50  Source: PayScale Inc.  ...    NaN
#
# [5 rows x 6 columns]

# %%
df
# Out:
#                      Undergraduate Major  ...     Group
# 0                             Accounting  ...  Business
# 1                  Aerospace Engineering  ...      STEM
# 2                            Agriculture  ...  Business
# 3                           Anthropology  ...      HASS
# 4                           Architecture  ...  Business
# 5                            Art History  ...      HASS
# 6                                Biology  ...      STEM
# 7                    Business Management  ...  Business
# 8                   Chemical Engineering  ...      STEM
# 9                              Chemistry  ...      STEM
# 10                     Civil Engineering  ...      STEM
# 11                        Communications  ...      HASS
# 12                  Computer Engineering  ...      STEM
# 13                      Computer Science  ...      STEM
# 14                          Construction  ...  Business
# 15                      Criminal Justice  ...      HASS
# ...

# %%
clean_df = df.dropna()
clean_df.tail()
# Out:
#    Undergraduate Major  ...  Group
# 45   Political Science  ...   HASS
# 46          Psychology  ...   HASS
# 47            Religion  ...   HASS
# 48           Sociology  ...   HASS
# 49             Spanish  ...   HASS
#
# [5 rows x 6 columns]

# %%
clean_df["Mid-Career Median Salary"].max()
index_max = clean_df['Mid-Career Median Salary'].idxmax()
clean_df["Undergraduate Major"][index_max]
# Out:
# 'Chemical Engineering'

# %%
index_min_starting = clean_df["Starting Median Salary"].idxmin()
clean_df['Undergraduate Major'][index_min_starting]
# Out:
# 'Spanish'

# %%
index_min = clean_df['Mid-Career Median Salary'].idxmin()
clean_df["Undergraduate Major"][index_min]
# Out:
# 'Education'

# %% [markdown]
# Majors with the Most Potential vs Lowest Risk

# %%
index_highest = (clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']).idxmax()
clean_df['Undergraduate Major'][index_highest]
# Out:
# 'Economics'

# %%
index_lowest = (clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']).idxmin()
clean_df['Undergraduate Major'][index_lowest]
# Out:
# 'Nursing'

# %%
    spread_col = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']
    clean_df.insert(1, 'Spread', spread_col)
    clean_df.head()
# Out:
#      Undergraduate Major    Spread  ...  Mid-Career 90th Percentile Salary     Group
# 0             Accounting  109800.0  ...                           152000.0  Business
# 1  Aerospace Engineering   96700.0  ...                           161000.0      STEM
# 2            Agriculture  113700.0  ...                           150000.0  Business
# 3           Anthropology  104200.0  ...                           138000.0      HASS
# 4           Architecture   85400.0  ...                           136000.0  Business
#
# [5 rows x 7 columns]

# %%
    low_risk = clean_df.sort_values('Spread', ascending=False)
    low_risk[['Undergraduate Major','Mid-Career 90th Percentile Salary', 'Spread']].head()
# Out:
#    Undergraduate Major  Mid-Career 90th Percentile Salary    Spread
# 17           Economics                           210000.0  159400.0
# 22             Finance                           195000.0  147800.0
# 37                Math                           183000.0  137800.0
# 36           Marketing                           175000.0  132900.0
# 42          Philosophy                           168000.0  132500.0

# %%
diff_salary_col = clean_df['Mid-Career Median Salary'] - clean_df['Starting Median Salary']
clean_df.insert(4, 'Salary Difference', diff_salary_col)
clean_df.head()
# Out:
#      Undergraduate Major    Spread  ...  Mid-Career 90th Percentile Salary     Group
# 0             Accounting  109800.0  ...                           152000.0  Business
# 1  Aerospace Engineering   96700.0  ...                           161000.0      STEM
# 2            Agriculture  113700.0  ...                           150000.0  Business
# 3           Anthropology  104200.0  ...                           138000.0      HASS
# 4           Architecture   85400.0  ...                           136000.0  Business
#
# [5 rows x 8 columns]

# %%
low_salary_diff = clean_df.sort_values('Salary Difference')
low_salary_diff[['Undergraduate Major','Salary Difference']].head()
# Out:
#     Undergraduate Major  Salary Difference
# 40              Nursing            12800.0
# 41            Nutrition            15400.0
# 32      Interior Design            17100.0
# 18            Education            17100.0
# 43  Physician Assistant            17400.0
